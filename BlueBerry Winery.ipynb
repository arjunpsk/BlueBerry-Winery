# %% [markdown]
# # Module 1 - Project 2 - Sprint 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Importing the red and white wine CSV from the folder "Wine Quality" in the folder of this project.

red_wine = pd.read_csv('Wine Quality/winequality-red.csv', sep=";") 
white_wine = pd.read_csv('Wine Quality/winequality-white.csv', sep=";") 
#df_names = pd.read_text('Wine Quality/winequality-names.txt')

# %%
# Display the head and tail of the red wine.
display(red_wine.head())
display(red_wine.tail())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
# Display the head and tail of the white wine.
display(white_wine.head())
display(white_wine.tail())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %%
# Summary of the red_wine dataframe

display(red_wine.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
# Summary of the white_wine dataframe

display(white_wine.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None

# %%
# The sapes of the dataframes.

display(red_wine.shape)
display(white_wine.shape)
# Out:
# (1599, 12)
# (4898, 12)

# %%
# Check to see if there are any rows with null in the red_wine dataframe

red_wine.iloc[ : , : ].isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Check to see if there are any rows with null in the white_wine dataframe

white_wine.iloc[ : , : ].isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Descriptive Stats on red wine list

red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# Descriptive Stats on white wine list

white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
# Red Wine
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# Here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low
# 1      9.8        5           low
# 2      9.8        5           low
# 3      9.8        6        medium
# 4      9.4        5           low

# %%
# White Wine
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# Here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality quality_label
# 0      8.8        6        medium
# 1      9.5        6        medium
# 2     10.1        6        medium
# 3      9.9        6        medium
# 4      9.9        6        medium

# %%
# Make a column to show what type of wine the row has. 
red_wine['wine_type'] = 'Red'
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label wine_type
# 0      9.4        5           low       Red
# 1      9.8        5           low       Red
# 2      9.8        5           low       Red
# 3      9.8        6        medium       Red
# 4      9.4        5           low       Red

# %%
# Make a column to show what type of wine the row has. 
white_wine['wine_type'] = 'White'
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality quality_label wine_type
# 0      8.8        6        medium     White
# 1      9.5        6        medium     White
# 2     10.1        6        medium     White
# 3      9.9        6        medium     White
# 4      9.9        6        medium     White

# %%
# Make a combined list of both red and white wines to a dataframe called Wines
wines = pd.concat([red_wine, white_wine])

# re-shuffle records just to randomize data points
wines = wines.sample(frac=1, random_state=42).reset_index(drop=True)

wines.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6487            6.1              0.22         0.46            1.80      0.160
# 6488           10.3              0.50         0.42            2.00      0.069
# 6489            6.4              0.31         0.53            8.80      0.057
# 6490            5.9              0.26         0.24            2.40      0.046
# 6491            8.0              0.34         0.49            9.00      0.033
# 6492            7.6              0.32         0.58           16.75      0.050
# 6493            5.6              0.28         0.27            3.90      0.043
# 6494            6.4              0.37         0.20            5.60      0.117
# 6495            6.5              0.26         0.50            8.00      0.051
# 6496            7.2              0.62         0.06            2.70      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6487                 34.0                  74.0  0.98840  3.19       0.33
# 6488                 21.0                  51.0  0.99820  3.16       0.72
# 6489                 36.0                 221.0  0.99642  3.17       0.44
# 6490                 27.0                 132.0  0.99234  3.63       0.73
# 6491                 39.0                 180.0  0.99360  3.13       0.38
# 6492                 43.0                 163.0  0.99990  3.15       0.54
# 6493                 52.0                 158.0  0.99202  3.35       0.44
# 6494                 61.0                 183.0  0.99459  3.24       0.43
# 6495                 46.0                 197.0  0.99536  3.18       0.47
# 6496                 15.0                  85.0  0.99746  3.51       0.54
#
#       alcohol  quality quality_label wine_type
# 6487     13.4        6        medium     White
# 6488     11.5        6        medium       Red
# 6489      9.1        5           low     White
# 6490     11.3        5           low     White
# 6491     12.3        8          high     White
# 6492      9.2        5           low     White
# 6493     10.7        7        medium     White
# 6494      9.5        5           low     White
# 6495      9.5        5           low     White
# 6496      9.5        5           low       Red

# %%
# Show list of specific quality
wines.loc[(wines["quality"] == 5)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.7              0.64         0.21            2.20      0.077
# 6               7.5              0.27         0.31           17.70      0.051
# 8               9.0              0.44         0.49            2.40      0.078
# 10              7.4              0.28         0.42           19.80      0.066
# 11              7.8              0.28         0.22            1.40      0.056
# ...             ...               ...          ...             ...        ...
# 6490            5.9              0.26         0.24            2.40      0.046
# 6492            7.6              0.32         0.58           16.75      0.050
# 6494            6.4              0.37         0.20            5.60      0.117
# 6495            6.5              0.26         0.50            8.00      0.051
# 6496            7.2              0.62         0.06            2.70      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                    32.0                 133.0  0.99560  3.27       0.45
# 6                    33.0                 173.0  0.99900  3.09       0.64
# 8                    26.0                 121.0  0.99780  3.23       0.58
# 10                   53.0                 195.0  1.00000  2.96       0.44
# 11                   24.0                 130.0  0.99440  3.28       0.48
# ...                   ...                   ...      ...   ...        ...
# 6490                 27.0                 132.0  0.99234  3.63       0.73
# 6492                 43.0                 163.0  0.99990  3.15       0.54
# 6494                 61.0                 183.0  0.99459  3.24       0.43
# 6495                 46.0                 197.0  0.99536  3.18       0.47
# 6496                 15.0                  85.0  0.99746  3.51       0.54
#
#       alcohol  quality quality_label wine_type
# 1         9.9        5           low       Red
# 6        10.2        5           low     White
# 8         9.2        5           low       Red
# 10        9.1        5           low     White
# 11        9.5        5           low     White
# ...       ...      ...           ...       ...
# 6490     11.3        5           low     White
# 6492      9.2        5           low     White
# 6494      9.5        5           low     White
# 6495      9.5        5           low     White
# 6496      9.5        5           low       Red
#
# [2138 rows x 14 columns]

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
wines['wine_type'] = pd.Categorical(wines['wine_type'],
categories=['Red', 'White'])
display(wines.value_counts("wine_type"))
display(wines.wine_type.value_counts().Red)
# Out:
# wine_type
# White    4898
# Red      1599
# dtype: int64
# 1599

# %%
# Total number of wines for each quality

wines.value_counts("quality")
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# dtype: int64

# %%
# Make two new dataframes without the first 3 columns (fixed acidity, volatile acidity, citric acid) of both red_wine and white_wine.

df2 = pd.DataFrame(red_wine.iloc[:,3:])
df2 = pd.DataFrame(df2.describe())
display(df2) 
df3 = pd.DataFrame(white_wine.iloc[:,3:])
df3 = pd.DataFrame(df3.describe())
display(df2) 

# Create a table to compare descriptive stats of both types of wines.

wines_describe = pd.concat([df2, df3], axis=1)

wines_describe = wines_describe.round(decimals = 2)
wines_describe
# Out:
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1599.000000  1599.000000          1599.000000           1599.000000
# mean         2.538806     0.087467            15.874922             46.467792
# std          1.409928     0.047065            10.460157             32.895324
# min          0.900000     0.012000             1.000000              6.000000
# 25%          1.900000     0.070000             7.000000             22.000000
# 50%          2.200000     0.079000            14.000000             38.000000
# 75%          2.600000     0.090000            21.000000             62.000000
# max         15.500000     0.611000            72.000000            289.000000
#
#            density           pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      0.996747     3.311113     0.658149    10.422983     5.636023
# std       0.001887     0.154386     0.169507     1.065668     0.807569
# min       0.990070     2.740000     0.330000     8.400000     3.000000
# 25%       0.995600     3.210000     0.550000     9.500000     5.000000
# 50%       0.996750     3.310000     0.620000    10.200000     6.000000
# 75%       0.997835     3.400000     0.730000    11.100000     6.000000
# max       1.003690     4.010000     2.000000    14.900000     8.000000
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1599.000000  1599.000000          1599.000000           1599.000000
# mean         2.538806     0.087467            15.874922             46.467792
# std          1.409928     0.047065            10.460157             32.895324
# min          0.900000     0.012000             1.000000              6.000000
# 25%          1.900000     0.070000             7.000000             22.000000
# 50%          2.200000     0.079000            14.000000             38.000000
# 75%          2.600000     0.090000            21.000000             62.000000
# max         15.500000     0.611000            72.000000            289.000000
#
#            density           pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      0.996747     3.311113     0.658149    10.422983     5.636023
# std       0.001887     0.154386     0.169507     1.065668     0.807569
# min       0.990070     2.740000     0.330000     8.400000     3.000000
# 25%       0.995600     3.210000     0.550000     9.500000     5.000000
# 50%       0.996750     3.310000     0.620000    10.200000     6.000000
# 75%       0.997835     3.400000     0.730000    11.100000     6.000000
# max       1.003690     4.010000     2.000000    14.900000     8.000000
#        residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# count         1599.00    1599.00              1599.00               1599.00
# mean             2.54       0.09                15.87                 46.47
# std              1.41       0.05                10.46                 32.90
# min              0.90       0.01                 1.00                  6.00
# 25%              1.90       0.07                 7.00                 22.00
# 50%              2.20       0.08                14.00                 38.00
# 75%              2.60       0.09                21.00                 62.00
# max             15.50       0.61                72.00                289.00
#
#        density       pH  sulphates  alcohol  quality  residual sugar  \
# count  1599.00  1599.00    1599.00  1599.00  1599.00         4898.00
# mean      1.00     3.31       0.66    10.42     5.64            6.39
# std       0.00     0.15       0.17     1.07     0.81            5.07
# min       0.99     2.74       0.33     8.40     3.00            0.60
# 25%       1.00     3.21       0.55     9.50     5.00            1.70
# 50%       1.00     3.31       0.62    10.20     6.00            5.20
# 75%       1.00     3.40       0.73    11.10     6.00            9.90
# max       1.00     4.01       2.00    14.90     8.00           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# min         0.01                 2.00                  9.00     0.99     2.72
# 25%         0.04                23.00                108.00     0.99     3.09
# 50%         0.04                34.00                134.00     0.99     3.18
# 75%         0.05                46.00                167.00     1.00     3.28
# max         0.35               289.00                440.00     1.04     3.82
#
#        sulphates  alcohol  quality
# count    4898.00  4898.00  4898.00
# mean        0.49    10.51     5.88
# std         0.11     1.23     0.89
# min         0.22     8.00     3.00
# 25%         0.41     9.50     5.00
# 50%         0.47    10.40     6.00
# 75%         0.55    11.40     6.00
# max         1.08    14.20     9.00

# %% [markdown]
# ![Tux, the Linux mascot](https://mdg.imgix.net/assets/images/tux.png?auto=format&fit=clip&q=40&w=100)
# > # Make comments on base observations on the two tables above.

# %% [markdown]
# # Starting with MatPlotLib

# %%
# Create a pie chart showing the types of wines.

plt.style.use("fivethirtyeight")

# Convert categories to dict

wines['wine_type'] = pd.Categorical(wines['wine_type'],
categories=['Red', 'White'])

wine_type_dict = list(wines.value_counts("wine_type"))
print(wine_type_dict)

display(wines.wine_type.value_counts().Red)

#Make function to display values instead of percentage on pie chart

def make_autopct(wine_type_dict):
    def my_autopct(pct):
        total = sum(wine_type_dict)
        val = int(round(pct*total/100.0))
        return '{p:.2f}% \n({v:d})'.format(p=pct,v=val)
    return my_autopct

def func(type_of_wine):
  return "{:1.1f}%".format(type_of_wine)
  
 


# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Red Wine', 'White Wine'
sizes = wines.value_counts("wine_type")
explode = (0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct=make_autopct(wine_type_dict),
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# display(wines.value_counts("wine_type" == "Red"))
# Out:
# [4898, 1599]
# 1599

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
ind = np.arange(N) # the x locations for the groups
width = 0.5
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ind, menMeans, width, color='r')
ax.bar(ind, womenMeans, width,bottom=menMeans, color='b')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
ax.set_yticks(np.arange(0, 81, 10))
ax.legend(labels=['Men', 'Women'])
plt.show()

# %%
# Create a dataframe of the counts in quality_label for red_wine 
rw_ql = pd.DataFrame(red_wine.value_counts("quality_label"))

# make an new index
rw_ql = rw_ql.reset_index()  

# change column names
rw_ql.columns = ['quality_label', 'Count for quality_label'] 

# re-order the list to show in the order "low, medium, high" instead of "medium, low, high"
lst = [1, 0, 2]
rw_ql = rw_ql.loc[lst]
rw_ql
# Out:
#   quality_label  Count for quality_label
# 1           low                      744
# 0        medium                      837
# 2          high                       18

# %%
# Bar plot for the quality counts of red_wine
red_wine_quality = rw_ql_vc.plot.bar(x='quality_label', y='Count for quality_label', rot=0,
legend=False, figsize=(8, 6), color="xkcd:reddish orange")

# %%
# Create a dataframe of the counts in quality_label for white_wine 
ww_ql = pd.DataFrame(white_wine.value_counts("quality_label"))

# make an new index
ww_ql = ww_ql.reset_index()  

# change column names
ww_ql.columns = ['quality_label', 'Count for quality_label'] 

# re-order the list to show in the order "low, medium, high" instead of "medium, low, high"
lst = [1, 0, 2]
ww_ql = ww_ql.loc[lst]
ww_ql
# Out:
#   quality_label  Count for quality_label
# 1           low                     1640
# 0        medium                     3078
# 2          high                      180

# %%
# Bar plot for the quality counts of white_wine
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)

# plt.bar_label(white_wine_quality.containers[0])
white_wine_quality = ww_ql.plot.bar(x='quality_label', y='Count for quality_label', rot=0, 
legend=False, figsize=(8, 6), color="xkcd:silver")

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
ind = np.arange(N) # the x locations for the groups
width = 0.5
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ind, menMeans, width, color='r')
ax.bar(ind, womenMeans, width,bottom=menMeans, color='b')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
ax.set_yticks(np.arange(0, 81, 10))
ax.legend(labels=['Men', 'Women'])
plt.show()

# %%
x = red_wine("quality_label")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/elysium/Documents/00_Code_Academy/Code_Academy Tasks/BlueBerry Winery/BlueBerry Winery.ipynb Cell 30' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/elysium/Documents/00_Code_Academy/Code_Academy%20Tasks/BlueBerry%20Winery/BlueBerry%20Winery.ipynb#ch0000033?line=0'>1</a> x = red_wine("quality_label")
#
# TypeError: 'DataFrame' object is not callable
